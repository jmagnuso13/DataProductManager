# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Crimes_-_2001_to_Present.csv")
df.head()
# Out:
#          ID Case Number                    Date               Block  IUCR  \
# 0  12218219    JD427864  11/11/2020 04:15:00 AM  071XX N HARLEM AVE  0610
# 1  12219254    JD429077  11/11/2020 08:00:00 PM   087XX W EVELYN LN  0820
# 2  12223460    JD433900  11/10/2020 12:00:00 PM   067XX N KEOTA AVE  1154
# 3  12220898    JD431023  10/25/2020 12:01:00 AM  069XX N OZANAM AVE  1154
# 4  12214964    JD424319  11/04/2020 12:10:00 PM   072XX N MEADE AVE  1330
#
#          Primary Type                              Description  \
# 0            BURGLARY                           FORCIBLE ENTRY
# 1               THEFT                           $500 AND UNDER
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4   CRIMINAL TRESPASS                                  TO LAND
#
#               Location Description  Arrest  Domestic  ...  Ward  \
# 0               SMALL RETAIL STORE   False     False  ...    41
# ...

# %%
df = df[df.Year != 2001]
df.shape
# Out:
# (62750, 22)

# %%
df.columns.values
# Out:
# array(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic',
#        'Beat', 'District', 'Ward', 'Community Area', 'FBI Code',
#        'X Coordinate', 'Y Coordinate', 'Year', 'Updated On', 'Latitude',
#        'Longitude', 'Location'], dtype=object)

# %%
df.columns = list(map(str, df.columns))
[print (type(x)) for x in df.columns.values]
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
df.shape

df['Year'] = df['Year'].astype(int)

df.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                float64
# Ward                      int64
# Community Area          float64
# FBI Code                 object
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %%
df.head()
# Out:
#          ID Case Number                    Date               Block  IUCR  \
# 0  12218219    JD427864  11/11/2020 04:15:00 AM  071XX N HARLEM AVE  0610
# 1  12219254    JD429077  11/11/2020 08:00:00 PM   087XX W EVELYN LN  0820
# 2  12223460    JD433900  11/10/2020 12:00:00 PM   067XX N KEOTA AVE  1154
# 3  12220898    JD431023  10/25/2020 12:01:00 AM  069XX N OZANAM AVE  1154
# 4  12214964    JD424319  11/04/2020 12:10:00 PM   072XX N MEADE AVE  1330
#
#          Primary Type                              Description  \
# 0            BURGLARY                           FORCIBLE ENTRY
# 1               THEFT                           $500 AND UNDER
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4   CRIMINAL TRESPASS                                  TO LAND
#
#               Location Description  Arrest  Domestic  ...  Ward  \
# 0               SMALL RETAIL STORE   False     False  ...    41
# ...

# %%
df2 = df[['Year', 'ID']]
df2.head()
# Out:
#    Year        ID
# 0  2020  12218219
# 1  2020  12219254
# 2  2020  12223460
# 3  2020  12220898
# 4  2020  12214964

# %%
df2['Year'].value_counts()


df3 = df2['Year'].value_counts().rename_axis('Year').reset_index(name='ID')

df3.head()
# Out:
#    Year    ID
# 0  2006  4256
# 1  2008  4169
# 2  2003  4141
# 3  2007  4124
# 4  2004  3783

# %%
df3.rename(columns={'ID':'Count'}, inplace=True)
df3.sort_values(['Year'], ascending=True, axis=0, inplace=True)

df3.head(20)



#ward41 = df['Year'].value_counts()
#ward41
# Out:
#     Year  Count
# 19  2001     47
# 12  2002   3098
# 2   2003   4141
# 4   2004   3783
# 5   2005   3725
# 0   2006   4256
# 3   2007   4124
# 1   2008   4169
# 6   2009   3675
# 10  2010   3177
# 7   2011   3339
# 9   2012   3190
# 8   2013   3218
# 11  2014   3140
# 14  2015   2926
# 13  2016   3072
# 15  2017   2745
# 16  2018   2735
# 17  2019   2655
# 18  2020   1582

# %%
df4 = df3[df3.Year != 2001]
df4
# Out:
#     Year  Count
# 12  2002   3098
# 2   2003   4141
# 4   2004   3783
# 5   2005   3725
# 0   2006   4256
# 3   2007   4124
# 1   2008   4169
# 6   2009   3675
# 10  2010   3177
# 7   2011   3339
# 9   2012   3190
# 8   2013   3218
# 11  2014   3140
# 14  2015   2926
# 13  2016   3072
# 15  2017   2745
# 16  2018   2735
# 17  2019   2655
# 18  2020   1582

# %%
import matplotlib.ticker

fig = plt.figure()
ax = plt.axes()

x = df4['Year']
y = df4['Count']
ax.plot(x, y);



locator = matplotlib.ticker.MultipleLocator(4)
plt.gca().xaxis.set_major_locator(locator)
formatter = matplotlib.ticker.StrMethodFormatter("{x:.0f}")
plt.gca().xaxis.set_major_formatter(formatter)
plt.title("Crime in the 41st Ward 2001-Present")
plt.xlabel("Year")
plt.ylabel("Count of Reported Crime");
plt.show()

# %%
# Out:
#       Count
# Year
# 2020   1582
# 2019   2655
# 2018   2735
# 2017   2745
# 2016   3072

# %%
import seaborn as sns

# %%
sns.barplot(data=df3, x="Year", y="Count")

# %%
print(plt.style.available)
mpl.style.use(['ggplot']) # optional: for ggplot-like style
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
# x-axis & y-axis values 
x = df3['Year']
y = df3['Count']
  
# create a figure and axes 
fig, ax = plt.subplots() 
  
# setting title to graph 
ax.set_title('Count of Crimes in 41st Ward 2002 - Present') 
  
# label x-axis and y-axis 
ax.set_ylabel('Count of Crimes') 
ax.set_xlabel('Year') 
  
# function to plot and show graph 
ax.plot(x, y) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-216-c05cb0629629> in <module>
#       1 # x-axis & y-axis values
# ...

# %%
import sys
# !{sys.executable} -m pip install sodapy

# %% [markdown]
# Reference socrata documentation here for more info on code below:
# https://github.com/xmunoz/sodapy

# %%
# make sure to install these packages before running:
# pip install pandas
#pip nstall sodapy

#import pandas as pd
#from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
#client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
#socrata_domain = "opendata.socrata.com"
#socrata_dataset_identifier = "f92i-ik66"
#MyAppToken = 'DuTwd7hDiMKeFtxIqiNojwzae'
#username = 'jason.magnuson@gmail.com'
#password = 'Niu13lax'
#client = Socrata('data.cityofchicago.org',
#                  MyAppToken,
#                  username,
#                  password)

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
#results = client.get("ijzp-q8t2.csv?district=016", limit=2000)

# Convert to pandas DataFrame
#results_df = pd.DataFrame.from_records(results)

# coding: utf-8

# # Example 01: Basic Queries
#
# Retrieving data from Socrata databases using sodapy

# ## Setup

# In[1]:


import os
import pandas as pd
import numpy as np

from sodapy import Socrata


# ## Find some data
#
# Though any organization can host their own data with Socrata's tools, Socrata also hosts several open datasets themselves:
#
# https://opendata.socrata.com/browse
#
# The following search options can help you find some great datasets for getting started:
# * Limit to data sets (pre-analyzed stuff is great, but if you're using sodapy you probably want the raw numbers!)
# * Sort by "Most Accessed"
#
# [Here's](https://opendata.socrata.com/browse?limitTo=datasets&sortBy=most_accessed&utf8=%E2%9C%93&page=1) a link that applies those filters automatically.
#
# Click on a few listings until you find one that looks interesting. Then click API and extract the following bits of data from the displayed url.
#
# https://<**opendata.socrata.com**>/dataset/Santa-Fe-Contributors/<**f92i-ik66**>.json
# https://data.cityofchicago.org/resource/qzdf-xmn8.json
#https://data.cityofchicago.org/resource/crimes.json

# ![Socrata Interface](socrata_interface.png)

# In[4]:


# Enter the information from those sections here
socrata_domain = "data.cityofchicago.org"
socrata_dataset_identifier = "crimes"

# App Tokens can be generated by creating an account at https://opendata.socrata.com/signup
# Tokens are optional (`None` can be used instead), though requests will be rate limited.
#
# If you choose to use a token, run the following command on the terminal (or add it to your .bashrc)
# $ export SODAPY_APPTOKEN=<token>
socrata_token = 'DuTwd7hDiMKeFtxIqiNojwzae'


# ## Get all the data

# In[5]:


client = Socrata(socrata_domain, socrata_token)
print(
    "Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(
        **client.__dict__
    )
)
# Out:
# Domain: data.cityofchicago.org
# Session: <requests.sessions.Session object at 0x1205b9310>
# URI Prefix: https://

# %%
results = client.get(socrata_dataset_identifier)
df = pd.DataFrame.from_dict(results)
df.head()
# Out:
#          id case_number                     date                  block  iucr  \
# 0  12223859    JD434473  2020-11-17T23:55:00.000      053XX S LAFLIN ST  041A
# 1  12223850    JD434451  2020-11-17T23:52:00.000        032XX W LAKE ST  0510
# 2  12223874    JD434460  2020-11-17T23:50:00.000        029XX W 59TH ST  1563
# 3  12223900    JD434464  2020-11-17T23:45:00.000  019XX S CANALPORT AVE  0460
# 4  12223890    JD434453  2020-11-17T23:37:00.000        015XX W 91ST ST  0430
#
#   primary_type                                        description  \
# 0      BATTERY                               AGGRAVATED - HANDGUN
# 1    RITUALISM  AGG. RITUAL MUTILATION - HANDS, FISTS, FEET, S...
# 2  SEX OFFENSE                              CRIMINAL SEXUAL ABUSE
# 3      BATTERY                                             SIMPLE
# 4      BATTERY                AGGRAVATED - OTHER DANGEROUS WEAPON
#
#      location_description  arrest  domestic  ... longitude location  \
# ...

# %%
# loop through complete dataset for 41st ward
loop_size = 3
num_loops = 2

for i in range(num_loops):
    results = client.get(
        socrata_dataset_identifier,
        select="name, amount",
        limit=loop_size,
        offset=loop_size * i,
    )
    print("\n> Loop number: {}".format(i))

    # This simply formats the output nicely
    for result in results:
        print(result)

where="amount < 2433",

# %%
df.shape
# Out:
# (1000, 30)

# %%
df.columns = list(map(str, df.columns))
[print (type(x)) for x in df.columns.values]
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
df2 = df[['year', 'id']]
df2['year'].value_counts()


df3 = df2['year'].value_counts().rename_axis('year').reset_index(name='id')

df3.rename(columns={'id':'count'}, inplace=True)
df3.sort_values(['year'], ascending=True, axis=0, inplace=True)
df3 = df3[df3.year != 2001]
df3.head(20)
# Out:
#    year  count
# 0  2020   1000
